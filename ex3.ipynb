# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# שלב 1:

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Bioinformatic data mining and analysis/ex3/brca_TCGA_norm_reads (1).csv', sep=',', header=0)
df=df.set_index('gene_id')
df['std'] = df.std(axis=1)
df
# Out:
#            TCGA-E9-A1RD  TCGA-E9-A1RD.1  TCGA-E9-A1RC  TCGA-E9-A1RC.1  \
# gene_id
# 100130426        0.0000          0.0000        0.0000          0.0000
# 100133144       11.6910         14.6549        1.2549         24.6974
# 100134869        2.9189          4.6414        1.1920         10.2728
# 10357          114.6254         76.4469      129.4521         83.1250
# 10431          763.7551        871.1649      906.7552       1004.9603
# ...                 ...             ...           ...             ...
# ZYX           2843.0214       2094.2947     2382.2424       1467.0139
# ZZEF1         1756.9164       1467.8073     2004.0199       1846.4782
# ZZZ3          1055.6419       1159.3233      755.3963        674.8512
# psiTPTE22      353.7457        440.4708      469.4573        260.6647
# tAKR             0.0000          0.0000        0.0000          0.0000
#
#            TCGA-AC-A8OP  TCGA-BH-A0B1  TCGA-B6-A0RG  TCGA-D8-A1JH  \
# gene_id
# ...

# %%
import statistics

# %%
statistics.mean(df['std'])
# Out:
# 739.1709472640916

# %%
np.quantile(df['std'],.25)
# Out:
# 38.32863567862047

# %% [markdown]
# נקח את ערך הסף להיות ערך הרבעות התחתון של סטיית התקן, ונסנן את הטבלה להיות רק הגנים שסטיית התקן שלהם גדולה מ 38

# %%
filtered_df=df[df['std'] > 38]
filtered_df
# Out:
#            TCGA-E9-A1RD  TCGA-E9-A1RD.1  TCGA-E9-A1RC  TCGA-E9-A1RC.1  \
# gene_id
# 10357          114.6254         76.4469      129.4521         83.1250
# 10431          763.7551        871.1649      906.7552       1004.9603
# 155060         186.8200        152.3123      129.3367        103.9187
# 340602           0.0000          0.0000        0.3496          0.0000
# 57714          778.9866        872.9658     1071.0478       1476.6865
# ...                 ...             ...           ...             ...
# ZYG11B        1520.9823       1050.7493     1805.1210        783.7302
# ZYX           2843.0214       2094.2947     2382.2424       1467.0139
# ZZEF1         1756.9164       1467.8073     2004.0199       1846.4782
# ZZZ3          1055.6419       1159.3233      755.3963        674.8512
# psiTPTE22      353.7457        440.4708      469.4573        260.6647
#
#            TCGA-AC-A8OP  TCGA-BH-A0B1  TCGA-B6-A0RG  TCGA-D8-A1JH  \
# gene_id
# ...

# %%
filtered_df=filtered_df.drop('std',1)
filtered_df
# Out:
# <ipython-input-8-114f3090a21d>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   filtered_df=filtered_df.drop('std',1)
#            TCGA-E9-A1RD  TCGA-E9-A1RD.1  TCGA-E9-A1RC  TCGA-E9-A1RC.1  \
# gene_id
# 10357          114.6254         76.4469      129.4521         83.1250
# 10431          763.7551        871.1649      906.7552       1004.9603
# 155060         186.8200        152.3123      129.3367        103.9187
# 340602           0.0000          0.0000        0.3496          0.0000
# 57714          778.9866        872.9658     1071.0478       1476.6865
# ...                 ...             ...           ...             ...
# ZYG11B        1520.9823       1050.7493     1805.1210        783.7302
# ZYX           2843.0214       2094.2947     2382.2424       1467.0139
# ZZEF1         1756.9164       1467.8073     2004.0199       1846.4782
# ...

# %% [markdown]
# שלב 2:

# %%
import seaborn as sns

# %%
t=filtered_df.T
t
# Out:
# gene_id            10357      10431     155060  340602      57714     653553  \
# TCGA-E9-A1RD    114.6254   763.7551   186.8200  0.0000   778.9866   178.1163
# TCGA-E9-A1RD.1   76.4469   871.1649   152.3123  0.0000   872.9658   172.1232
# TCGA-E9-A1RC    129.4521   906.7552   129.3367  0.3496  1071.0478   144.3677
# TCGA-E9-A1RC.1   83.1250  1004.9603   103.9187  0.0000  1476.6865  1393.3532
# TCGA-AC-A8OP     83.6918   756.3169  1021.3643  0.0000   971.1502   599.4627
# ...                  ...        ...        ...     ...        ...        ...
# TCGA-B6-A1KC     95.9220  1074.7905    90.9091  0.0000   483.2366    82.5274
# TCGA-A2-A0CK    113.6646   795.5556   263.0303  2.0202   132.1212   479.1919
# TCGA-E2-A574    216.1223  1481.4815   170.5948  0.0000    59.4837   207.6319
# TCGA-AR-A1AH    126.1252  2325.5034   157.6271  1.6769   507.4252    19.7872
# TCGA-D8-A1J9     95.7980   819.9895   109.6285  0.0000  1638.6709   334.3799
#
# ...

# %%
#t_df=np.transpose(filtered_df)
#t_df
# Out:
# gene_id            10357      10431     155060  340602      57714     653553  \
# TCGA-E9-A1RD    114.6254   763.7551   186.8200  0.0000   778.9866   178.1163
# TCGA-E9-A1RD.1   76.4469   871.1649   152.3123  0.0000   872.9658   172.1232
# TCGA-E9-A1RC    129.4521   906.7552   129.3367  0.3496  1071.0478   144.3677
# TCGA-E9-A1RC.1   83.1250  1004.9603   103.9187  0.0000  1476.6865  1393.3532
# TCGA-AC-A8OP     83.6918   756.3169  1021.3643  0.0000   971.1502   599.4627
# ...                  ...        ...        ...     ...        ...        ...
# TCGA-B6-A1KC     95.9220  1074.7905    90.9091  0.0000   483.2366    82.5274
# TCGA-A2-A0CK    113.6646   795.5556   263.0303  2.0202   132.1212   479.1919
# TCGA-E2-A574    216.1223  1481.4815   170.5948  0.0000    59.4837   207.6319
# TCGA-AR-A1AH    126.1252  2325.5034   157.6271  1.6769   507.4252    19.7872
# TCGA-D8-A1J9     95.7980   819.9895   109.6285  0.0000  1638.6709   334.3799
#
# ...

# %%
#sns.clustermap(t_df,method='weighted',metric='euclidean',row_cluster=True, col_cluster=True)

# %%
sns.clustermap(t,method='weighted',metric='euclidean',row_cluster=True, col_cluster=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
#המרה ללוג 10
t=t.replace(0,0.0000001)
t_log=t.transform(np.log10)
t_log
# Out:
# gene_id            10357     10431    155060    340602     57714    653553  \
# TCGA-E9-A1RD    2.059281  2.882954  2.271423 -7.000000  2.891530  2.250704
# TCGA-E9-A1RD.1  1.883360  2.940100  2.182735 -7.000000  2.940997  2.235839
# TCGA-E9-A1RC    2.112109  2.957490  2.111722 -0.456429  3.029809  2.159470
# TCGA-E9-A1RC.1  1.919732  3.002149  2.016694 -7.000000  3.169288  3.144061
# TCGA-AC-A8OP    1.922683  2.878704  3.009181 -7.000000  2.987286  2.777762
# ...                  ...       ...       ...       ...       ...       ...
# TCGA-B6-A1KC    1.981918  3.031324  1.958607 -7.000000  2.684160  1.916598
# TCGA-A2-A0CK    2.055625  2.900671  2.420006  0.305394  2.120973  2.680509
# TCGA-E2-A574    2.334700  3.170696  2.231966 -7.000000  1.774398  2.317294
# TCGA-AR-A1AH    2.100802  3.366517  2.197631  0.224507  2.705372  1.296384
# TCGA-D8-A1J9    1.981356  2.913808  2.039923 -7.000000  3.214492  2.524240
#
# ...

# %%
#t_df_log=t.replace(0,0.0000001)
#t_df_log=t_df_log.transform(np.log10)
#t_df_log

# %%
sns.clustermap(t_log,method='weighted',metric='euclidean',row_cluster=True, col_cluster=True,figsize=(20, 25))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
t=t.replace(0,1)
t_log=t.transform(np.log10)
t_log
# Out:
# gene_id            10357     10431    155060    340602     57714    653553  \
# TCGA-E9-A1RD    2.059281  2.882954  2.271423 -7.000000  2.891530  2.250704
# TCGA-E9-A1RD.1  1.883360  2.940100  2.182735 -7.000000  2.940997  2.235839
# TCGA-E9-A1RC    2.112109  2.957490  2.111722 -0.456429  3.029809  2.159470
# TCGA-E9-A1RC.1  1.919732  3.002149  2.016694 -7.000000  3.169288  3.144061
# TCGA-AC-A8OP    1.922683  2.878704  3.009181 -7.000000  2.987286  2.777762
# ...                  ...       ...       ...       ...       ...       ...
# TCGA-B6-A1KC    1.981918  3.031324  1.958607 -7.000000  2.684160  1.916598
# TCGA-A2-A0CK    2.055625  2.900671  2.420006  0.305394  2.120973  2.680509
# TCGA-E2-A574    2.334700  3.170696  2.231966 -7.000000  1.774398  2.317294
# TCGA-AR-A1AH    2.100802  3.366517  2.197631  0.224507  2.705372  1.296384
# TCGA-D8-A1J9    1.981356  2.913808  2.039923 -7.000000  3.214492  2.524240
#
# ...

# %%
sns.clustermap(t_log,method='weighted',metric='euclidean',row_cluster=True, col_cluster=True,figsize=(20, 25))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# תכתבו פסקה שמתארת את התמונה שקיבלתם ואשר מוספיקה מסקנות שלכם לגבי המשמעות של הקלסטור ומה זה אומר על דוגמאות סרטן השד. למשל, כמה סוגים שונים של סרטן שד אתם משערים שיש על סמך פרופילים של ביטוי הגנים? תקחו השראה מתמונה 1 -תמונה 3 במאמר ה -Molecular portraits.

# %% [markdown]
# על ציר ה
# X
# יש דנדוגרמה של הגנים, מקלוסטרים לפי שיטת קליסטור הירארכי כאשר המרחקים מחושבים לפי חישוב אוקלידיאני והאיחוד בין קבוצות הוא לפי
# WPGMA
# (מסקירה במאמר היה נראה לי שזו השיטה בה הם השתמשו)
# וכנ"ל על ציר
# Y,
# רק שהקליסטור הוא עבור הדוגמאות.
# ככל שהצבע יותר כהה זה אומר שהיה םחות ביטוי של הגן בדוגמא, וככל שהוא יותר
# בהיר זה אומר שהיה יותר ביטוי של הגן בדוגמא.
# מבסתכלות בדנדוגרמה של הדנים ןבמפת החום ניתן לראות כי הגנים מתחלקים ל2 קבוצות עיקריות, ובתוכן לעוד תתי קבוצות.
# קבוצה אחת (השמאלית יותר) צבעיה הכללי בהיר יותר, כלומר ניתן להסיק שהיא מראה ביטוי יתר של גנים, ניתן להסיק שאלו גנים במתבטאים באופן מוגבר במצב של סרטן שד, קבוצה שניה (הימנית יותר), צבעה הכללי כהה יותר( למרות שגם בה יש אזורים בהירים) ולכן ניתן להסיק שגנים מקבוצה זו נוטים להתבטא פחות במצב של סרטן שד.
#  דבר נוסף שניתן להבחין בו מהסתכלות על מפת החום זה שהחלוקה העיקרית היא בין גנים ולא בין דוגמאות, מזה אני מסיקה שהשוני בין הגנים גדול מאשר השוני בין הדוגמאות שנבדקו.
#  מהסתכלות בדנדוגרמה של הדוגמאות אפשר לראות חלוקה עדינה ל2 קבוצות עיקריות, מכך ניתן להסיק שיש 2 סוגי סרטן שד.
